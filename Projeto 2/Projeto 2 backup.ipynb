# %% [markdown]
# # **Meta 1**

# %% [markdown]
# Simular no software CoppeliaSim um robô móvel com
# acionamento diferencial, de maneira que o mesmo receba os
# comandos das velocidades de referências para as rodas e retorne a
# posição e orientação do robô ($x,y,\theta$) em um referencial global.
#
# Além do movimento do robô no espaço de trabalho, mostrar os seguintes gráficos:
# * Velocidades das rodas (entradas) em função do tempo;
# * Configuração do robô ($x,y,\theta$), (saídas), em função do tempo;
# * Gráfico das posições ($x(t),y(t)$) seguidas pelo robô no plano $xy$.

# %% [markdown]
# https://manual.coppeliarobotics.com/
#
# https://manual.coppeliarobotics.com/en/remoteApiFunctionsPython.htm

# %% [markdown]
# Obs.: Inserir as seguintes linhas ao script do robô para ser desenhado o caminho
#
# ```lua
# --lua
#
# sim = require('sim')
#
# function sysCall_init()
#     robot = sim.getObject('.')
#     robotTrace = sim.addDrawingObject(sim.drawing_linestrip + sim.drawing_cyclic, 8, 0, -1, 400, {1, 1, 0}, nil, nil, {1, 1, 0})
# end
#
# function sysCall_sensing()
#     local p = sim.getObjectPosition(robot)
#     p[3]=0
#     sim.addDrawingObjectItem(robotTrace, p)
# end
# ```

# %%
try:
    import sim
except:
    print ('--------------------------------------------------------------')
    print ('"sim.py" could not be imported. This means very probably that')
    print ('either "sim.py" or the remoteApi library could not be found.')
    print ('Make sure both are in the same folder as this file,')
    print ('or appropriately adjust the file "sim.py"')
    print ('--------------------------------------------------------------')
    print ('')

import time
import numpy as np
import matplotlib.pyplot as plt
import guira

# %%
import sim
import matplotlib.pyplot as plt

def get_object_bounding_box(clientID, obj_handle):
    res, min_x = sim.simxGetObjectFloatParameter(clientID, obj_handle, sim.sim_objfloatparam_modelbbox_min_x, sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print(f'Erro ao obter min_x para o objeto {obj_handle}')
        return None, None
    res, max_x = sim.simxGetObjectFloatParameter(clientID, obj_handle, sim.sim_objfloatparam_modelbbox_max_x, sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print(f'Erro ao obter max_x para o objeto {obj_handle}')
        return None, None
    res, min_y = sim.simxGetObjectFloatParameter(clientID, obj_handle, sim.sim_objfloatparam_modelbbox_min_y, sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print(f'Erro ao obter min_y para o objeto {obj_handle}')
        return None, None
    res, max_y = sim.simxGetObjectFloatParameter(clientID, obj_handle, sim.sim_objfloatparam_modelbbox_max_y, sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print(f'Erro ao obter max_y para o objeto {obj_handle}')
        return None, None

    width = max_x - min_x
    height = max_y - min_y

    return width, height

def is_within_area(x, y, x_center, y_center, distance):
    return abs(x - x_center) <= distance and abs(y - y_center) <= distance

# Conectar-se ao CoppeliaSim
sim.simxFinish(-1)  # Fechar todas as conexões existentes
clientID = sim.simxStart('127.0.0.1', 19999, True, True, 5000, 5)

# Inicializar lista de retângulos
rectangles = []

if clientID != -1:
    print('Conectado ao CoppeliaSim')

    # Obter o handle do robô e do destino
    res, pioneer_handle = sim.simxGetObjectHandle(clientID, 'Pioneer_p3dx', sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print('Erro ao obter o handle do PioneerP3DX')
        pioneer_handle = None

    res, goal_handle = sim.simxGetObjectHandle(clientID, 'Goal', sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print('Erro ao obter o handle do Goal')
        goal_handle = None

    # Obter a posição do Pioneer e do Goal
    res, pioneer_pos = sim.simxGetObjectPosition(clientID, pioneer_handle, -1, sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print('Erro ao obter a posição do PioneerP3DX')
        pioneer_pos = (0, 0)

    res, goal_pos = sim.simxGetObjectPosition(clientID, goal_handle, -1, sim.simx_opmode_blocking)
    if res != sim.simx_return_ok:
        print('Erro ao obter a posição do Goal')
        goal_pos = (0, 0)

    # Obter todos os objetos na simulação
    res, objects = sim.simxGetObjects(clientID, sim.sim_handle_all, sim.simx_opmode_blocking)
    if res == sim.simx_return_ok:
        print('Número de objetos na simulação:', len(objects))

        for obj in objects:
            # Ignorar o robô e o destino
            if obj in [pioneer_handle, goal_handle]:
                continue

            # Obter a posição do objeto
            res, position = sim.simxGetObjectPosition(clientID, obj, -1, sim.simx_opmode_blocking)
            if res == sim.simx_return_ok:
                print(f'Posição do objeto {obj}:', position)

                # Obter as dimensões do objeto
                width, height = get_object_bounding_box(clientID, obj)
                if width is not None and height is not None:
                    print(f'Dimensões do objeto {obj} - Largura: {width}, Altura: {height}')
                    
                    # Filtrar objetos que podem ser quadrantes indesejados
                    if width > 2 and height > 2:  # Ajuste os critérios conforme necessário
                        print(f'Ignorando o objeto {obj} por ser um quadrante indesejado')
                        continue

                    # Verificar se o objeto está dentro da área ao redor do Pioneer e do Goal
                    if (is_within_area(position[0], position[1], pioneer_pos[0], pioneer_pos[1], 1) or
                        is_within_area(position[0], position[1], goal_pos[0], goal_pos[1], 1)):
                        print(f'Ignorando o objeto {obj} por estar dentro da área ao redor do Pioneer ou Goal')
                        continue

                    # Adicionar retângulo à lista (x, y, largura, altura)
                    rectangles.append((position[0], position[1], width, height))
                else:
                    print(f'Erro ao obter as dimensões do objeto {obj}')
            else:
                print(f'Erro ao obter a posição do objeto {obj}')

    else:
        print('Erro ao obter objetos:', res)

    # Desconectar-se do CoppeliaSim
    sim.simxFinish(clientID)
    print('Desconectado do CoppeliaSim')
else:
    print('Falha ao conectar-se ao CoppeliaSim')
# Out:
# Conectado ao CoppeliaSim
# Número de objetos na simulação: 185
# Posição do objeto 0: [0.5934158563613892, -9.363414764404297, 8.86629867553711]
# Dimensões do objeto 0 - Largura: 0.05000000074505806, Altura: 0.14000000059604645
# Posição do objeto 1: [0.0, 0.0, 0.75]
# Erro ao obter min_x para o objeto 1
# Erro ao obter as dimensões do objeto 1
# Posição do objeto 2: [20.0, 0.0, 0.75]
# Erro ao obter min_x para o objeto 2
# Erro ao obter as dimensões do objeto 2
# Posição do objeto 3: [0.0, 20.0, 0.75]
# Erro ao obter min_x para o objeto 3
# Erro ao obter as dimensões do objeto 3
# Posição do objeto 4: [0.0, 0.0, 20.75]
# Erro ao obter min_x para o objeto 4
# Erro ao obter as dimensões do objeto 4
# Posição do objeto 5: [-20.0, -1.748455588312936e-06, 0.75]
# Erro ao obter min_x para o objeto 5
# Erro ao obter as dimensões do objeto 5
# Posição do objeto 6: [1.748455588312936e-06, -20.0, 0.75]
# Erro ao obter min_x para o objeto 6
# Erro ao obter as dimensões do objeto 6
# Posição do objeto 7: [1.8140226529794745e-06, 1.5858690229075822e-13, -20.75]
# Erro ao obter min_x para o objeto 7
# Erro ao obter as dimensões do objeto 7
# Posição do objeto 8: [0.0, 0.0, 0.0]
# Dimensões do objeto 8 - Largura: 0.009999999776482582, Altura: 0.009999999776482582
# Posição do objeto 9: [1.5535461902618408, -0.8391069173812866, 2.5]
# Erro ao obter min_x para o objeto 9
# Erro ao obter as dimensões do objeto 9
# Posição do objeto 10: [-0.1828123927116394, 1.8430930376052856, 2.5]
# Erro ao obter min_x para o objeto 10
# Erro ao obter as dimensões do objeto 10
# Posição do objeto 11: [-1.150916337966919, -1.2177112102508545, 2.5]
# Erro ao obter min_x para o objeto 11
# Erro ao obter as dimensões do objeto 11
# Posição do objeto 12: [0.0, -3.019916050561733e-07, 2.5]
# Erro ao obter min_x para o objeto 12
# Erro ao obter as dimensões do objeto 12
# Posição do objeto 14: [-4.030877590179443, -3.040497303009033, 0.09750732034444809]
# Dimensões do objeto 14 - Largura: 0.19534281641244888, Altura: 0.1953471079468727
# Ignorando o objeto 14 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 15: [-4.030874729156494, -3.0404953956604004, 0.09750136733055115]
# Dimensões do objeto 15 - Largura: 0.1950892210006714, Altura: 0.1950891613960266
# Ignorando o objeto 15 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 16: [-4.030884742736816, -3.040494918823242, 0.09750141948461533]
# Dimensões do objeto 16 - Largura: 0.1950218826532364, Altura: 0.04999663680791855
# Ignorando o objeto 16 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 17: [-4.030883312225342, -2.7094972133636475, 0.0975068211555481]
# Dimensões do objeto 17 - Largura: 0.19534426927566528, Altura: 0.19534819573163986
# Ignorando o objeto 17 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 18: [-4.030884742736816, -2.7095000743865967, 0.09750168025493622]
# Dimensões do objeto 18 - Largura: 0.195089191198349, Altura: 0.19508913904428482
# Ignorando o objeto 18 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 19: [-4.030890464782715, -2.709501266479492, 0.09750156104564667]
# Dimensões do objeto 19 - Largura: 0.1950218826532364, Altura: 0.04999660700559616
# Ignorando o objeto 19 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 20: [-4.224364280700684, -2.8749911785125732, 0.060547810047864914]
# Dimensões do objeto 20 - Largura: 0.0697430893778801, Altura: 0.03553996980190277
# Ignorando o objeto 20 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 21: [-4.224369049072266, -2.8749916553497314, 0.06055314093828201]
# Dimensões do objeto 21 - Largura: 0.07489605993032455, Altura: 0.048812124878168106
# Ignorando o objeto 21 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 22: [-4.202103137969971, -2.8750038146972656, 0.029525868594646454]
# Dimensões do objeto 22 - Largura: 0.05956488288938999, Altura: 0.059574199840426445
# Ignorando o objeto 22 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 23: [-4.202108383178711, -2.8750016689300537, 0.02959892526268959]
# Dimensões do objeto 23 - Largura: 0.05919802188873291, Altura: 0.05919813737273216
# Ignorando o objeto 23 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 24: [-4.202115058898926, -2.8750016689300537, 0.02959892526268959]
# Dimensões do objeto 24 - Largura: 0.05919802188873291, Altura: 0.05919813737273216
# Ignorando o objeto 24 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 25: [-4.2165751457214355, -2.8749961853027344, 0.04021833837032318]
# Dimensões do objeto 25 - Largura: 0.05105866864323616, Altura: 0.03551887348294258
# Ignorando o objeto 25 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 26: [-4.0755510330200195, -2.8749942779541016, 0.13868923485279083]
# Dimensões do objeto 26 - Largura: 0.519000768661499, Altura: 0.41499966382980347
# Ignorando o objeto 26 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 27: [-3.9692888259887695, -2.7367961406707764, 0.20699644088745117]
# Erro ao obter min_x para o objeto 27
# Erro ao obter as dimensões do objeto 27
# Posição do objeto 28: [-3.9202585220336914, -2.7499470710754395, 0.20709267258644104]
# Erro ao obter min_x para o objeto 28
# Erro ao obter as dimensões do objeto 28
# Posição do objeto 29: [-3.8850836753845215, -2.791865110397339, 0.20715925097465515]
# Erro ao obter min_x para o objeto 29
# Erro ao obter as dimensões do objeto 29
# Posição do objeto 30: [-3.866508960723877, -2.8477253913879395, 0.20719939470291138]
# Erro ao obter min_x para o objeto 30
# Erro ao obter as dimensões do objeto 30
# Posição do objeto 31: [-3.8665096759796143, -2.9022722244262695, 0.2072041630744934]
# Erro ao obter min_x para o objeto 31
# Erro ao obter as dimensões do objeto 31
# Posição do objeto 32: [-3.8851373195648193, -2.9535000324249268, 0.20718032121658325]
# Erro ao obter min_x para o objeto 32
# Erro ao obter as dimensões do objeto 32
# Posição do objeto 33: [-3.920156717300415, -2.9952359199523926, 0.20711210370063782]
# Erro ao obter min_x para o objeto 33
# Erro ao obter as dimensões do objeto 33
# Posição do objeto 34: [-3.969310760498047, -3.013139486312866, 0.20701147615909576]
# Erro ao obter min_x para o objeto 34
# Erro ao obter as dimensões do objeto 34
# Posição do objeto 35: [-4.186001777648926, -3.013136625289917, 0.2066446840763092]
# Erro ao obter min_x para o objeto 35
# Erro ao obter as dimensões do objeto 35
# Posição do objeto 36: [-4.235249996185303, -2.995225667953491, 0.20654046535491943]
# Erro ao obter min_x para o objeto 36
# Erro ao obter as dimensões do objeto 36
# Posição do objeto 37: [-4.270263671875, -2.9534835815429688, 0.2064678966999054]
# Erro ao obter min_x para o objeto 37
# Erro ao obter as dimensões do objeto 37
# Posição do objeto 38: [-4.288898468017578, -2.9022579193115234, 0.20641687512397766]
# Erro ao obter min_x para o objeto 38
# Erro ao obter as dimensões do objeto 38
# Posição do objeto 39: [-4.288887023925781, -2.8477089405059814, 0.20642691850662231]
# Erro ao obter min_x para o objeto 39
# Erro ao obter as dimensões do objeto 39
# Posição do objeto 40: [-4.270280838012695, -2.796483278274536, 0.20644737780094147]
# Erro ao obter min_x para o objeto 40
# Erro ao obter as dimensões do objeto 40
# Posição do objeto 41: [-4.235249042510986, -2.7547202110290527, 0.2065269947052002]
# Erro ao obter min_x para o objeto 41
# Erro ao obter as dimensões do objeto 41
# Posição do objeto 42: [-4.186003684997559, -2.736788034439087, 0.20662768185138702]
# Erro ao obter min_x para o objeto 42
# Erro ao obter as dimensões do objeto 42
# Posição do objeto 43: [-4.031284809112549, -2.8749923706054688, 0.23707450926303864]
# Erro ao obter min_x para o objeto 43
# Erro ao obter as dimensões do objeto 43
# Posição do objeto 44: [-3.911287307739258, -2.8749964237213135, 0.23731526732444763]
# Erro ao obter min_x para o objeto 44
# Erro ao obter as dimensões do objeto 44
# Posição do objeto 45: [-4.031284332275391, -2.74499249458313, 0.2370670884847641]
# Erro ao obter min_x para o objeto 45
# Erro ao obter as dimensões do objeto 45
# Posição do objeto 46: [-4.031283378601074, -3.0049924850463867, 0.23708175122737885]
# Erro ao obter min_x para o objeto 46
# Erro ao obter as dimensões do objeto 46
# Posição do objeto 47: [-3.9393553733825684, -2.783071756362915, 0.2372492551803589]
# Erro ao obter min_x para o objeto 47
# Erro ao obter as dimensões do objeto 47
# Posição do objeto 48: [-3.939383029937744, -2.966919422149658, 0.23726853728294373]
# Erro ao obter min_x para o objeto 48
# Erro ao obter as dimensões do objeto 48
# Posição do objeto 49: [-4.241294860839844, -2.874983787536621, 0.23665575683116913]
# Erro ao obter min_x para o objeto 49
# Erro ao obter as dimensões do objeto 49
# Posição do objeto 50: [-4.213149547576904, -2.7699849605560303, 0.2367117553949356]
# Erro ao obter min_x para o objeto 50
# Erro ao obter as dimensões do objeto 50
# Posição do objeto 51: [-4.213165760040283, -2.979985475540161, 0.23671948909759521]
# Erro ao obter min_x para o objeto 51
# Erro ao obter as dimensões do objeto 51
# Posição do objeto 52: [-4.121308326721191, -2.8749887943267822, 0.2368924915790558]
# Erro ao obter min_x para o objeto 52
# Erro ao obter as dimensões do objeto 52
# Posição do objeto 53: [-3.8559627532958984, -2.8750088214874268, 0.06801804155111313]
# Erro ao obter min_x para o objeto 53
# Erro ao obter as dimensões do objeto 53
# Posição do objeto 54: [-4.07558012008667, -2.874995470046997, 0.13867972791194916]
# Dimensões do objeto 54 - Largura: 0.530009001493454, Altura: 0.5300002843141556
# Ignorando o objeto 54 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 55: [-3.8410189151763916, -2.6399896144866943, 0.3741171956062317]
# Dimensões do objeto 55 - Largura: 0.5300001502037048, Altura: 0.5300002694129944
# Ignorando o objeto 55 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 57: [3.6850037574768066, 2.4600000381469727, 0.3737891614437103]
# Dimensões do objeto 57 - Largura: 0.5300001502037048, Altura: 0.5300002694129944
# Ignorando o objeto 57 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 58: [0.0, 0.0, 0.0]
# Dimensões do objeto 58 - Largura: 10.000003814697266, Altura: 10.000003814697266
# Ignorando o objeto 58 por ser um quadrante indesejado
# Posição do objeto 59: [-2.5, -2.5, -0.020000072196125984]
# Dimensões do objeto 59 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 59 por ser um quadrante indesejado
# Posição do objeto 60: [-2.5, -2.5, 3.5390257835388184e-08]
# Dimensões do objeto 60 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 60 por ser um quadrante indesejado
# Posição do objeto 61: [-2.5, 2.5, -0.020000072196125984]
# Dimensões do objeto 61 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 61 por ser um quadrante indesejado
# Posição do objeto 62: [-2.5, 2.5, 3.5390257835388184e-08]
# Dimensões do objeto 62 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 62 por ser um quadrante indesejado
# Posição do objeto 63: [2.5, -2.5, -0.020000072196125984]
# Dimensões do objeto 63 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 63 por ser um quadrante indesejado
# Posição do objeto 64: [2.5, -2.5, 3.5390257835388184e-08]
# Dimensões do objeto 64 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 64 por ser um quadrante indesejado
# Posição do objeto 65: [2.5, 2.5, -0.020000072196125984]
# Dimensões do objeto 65 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 65 por ser um quadrante indesejado
# Posição do objeto 66: [2.5, 2.5, 3.5390257835388184e-08]
# Dimensões do objeto 66 - Largura: 5.000003814697266, Altura: 5.000003814697266
# Ignorando o objeto 66 por ser um quadrante indesejado
# Posição do objeto 67: [-0.40230607986450195, -0.4000001847743988, 0.37600061297416687]
# Dimensões do objeto 67 - Largura: 0.7520008087158203, Altura: 1.599043071269989
# Posição do objeto 68: [-0.40000006556510925, -0.40000003576278687, 0.3760001063346863]
# Dimensões do objeto 68 - Largura: 3.1990456581115723, Altura: 1.5990431308746338
# Posição do objeto 69: [-0.7250000238418579, -1.5249993801116943, 0.4500003755092621]
# Dimensões do objeto 69 - Largura: 0.40002088248729706, Altura: 0.4500184655189514
# Posição do objeto 70: [-0.7250000238418579, -1.524999976158142, 0.450000137090683]
# Dimensões do objeto 70 - Largura: 0.4000004827976227, Altura: 0.4500003457069397
# Posição do objeto 71: [1.6750000715255737, -0.4750000536441803, 0.16500011086463928]
# Dimensões do objeto 71 - Largura: 0.7853469848632812, Altura: 0.784098893404007
# Posição do objeto 72: [1.6968016624450684, -0.5171322822570801, 0.5524148941040039]
# Dimensões do objeto 72 - Largura: 0.7840988636016846, Altura: 0.7853469848632812
# Posição do objeto 73: [2.6750001907348633, -1.2000000476837158, 0.16500011086463928]
# Dimensões do objeto 73 - Largura: 0.7853469848632812, Altura: 0.784098893404007
# Posição do objeto 74: [2.6968016624450684, -1.242132306098938, 0.5524148941040039]
# Dimensões do objeto 74 - Largura: 0.7840988636016846, Altura: 0.7853469848632812
# Posição do objeto 75: [3.7250001430511475, -1.9250000715255737, 0.16500011086463928]
# Dimensões do objeto 75 - Largura: 0.7853469848632812, Altura: 0.784098893404007
# Posição do objeto 76: [3.7468016147613525, -1.9671322107315063, 0.5524148941040039]
# Dimensões do objeto 76 - Largura: 0.7840988636016846, Altura: 0.7853469848632812
# Posição do objeto 77: [-2.299999952316284, 4.224999904632568, 0.0]
# Dimensões do objeto 77 - Largura: 0.3411158621311188, Altura: 0.523238867521286
# Posição do objeto 78: [-2.299999952316284, 4.22499942779541, 0.9153702855110168]
# Dimensões do objeto 78 - Largura: 1.6774763464927673, Altura: 0.3410441428422928
# Posição do objeto 79: [-2.3049676418304443, 4.2253241539001465, 1.1776396036148071]
# Dimensões do objeto 79 - Largura: 0.256468266248703, Altura: 0.523238867521286
# Posição do objeto 80: [-2.3287694454193115, 4.390070915222168, 1.2911649942398071]
# Dimensões do objeto 80 - Largura: 0.12705828621983528, Altura: 0.6341636327560991
# Posição do objeto 81: [-2.3305768966674805, 4.435650825500488, 1.1404534578323364]
# Dimensões do objeto 81 - Largura: 0.1270182877779007, Altura: 0.10169515013694763
# Posição do objeto 82: [-2.328852891921997, 4.39007043838501, 1.048477292060852]
# Dimensões do objeto 82 - Largura: 0.12308920174837112, Altura: 0.391048529651016
# Posição do objeto 83: [-2.3285634517669678, 4.440672397613525, 0.855260968208313]
# Dimensões do objeto 83 - Largura: 0.123045913875103, Altura: 0.09161263704299927
# Posição do objeto 84: [-2.326201915740967, 4.441308498382568, 0.8539825081825256]
# Erro ao obter min_x para o objeto 84
# Erro ao obter as dimensões do objeto 84
# Posição do objeto 85: [-2.3287696838378906, 4.059927940368652, 1.2911649942398071]
# Dimensões do objeto 85 - Largura: 0.12776324898004532, Altura: 0.6342060680035502
# Posição do objeto 86: [-2.3313190937042236, 4.01450777053833, 1.1404848098754883]
# Dimensões do objeto 86 - Largura: 0.12772336602210999, Altura: 0.10211992636322975
# Posição do objeto 87: [-2.3288559913635254, 4.059927940368652, 1.0484774112701416]
# Dimensões do objeto 87 - Largura: 0.12311248481273651, Altura: 0.3910610326565802
# Posição do objeto 88: [-2.3286020755767822, 4.0090651512146, 0.85526442527771]
# Dimensões do objeto 88 - Largura: 0.12304601073265076, Altura: 0.09161162376403809
# Posição do objeto 89: [-2.3262405395507812, 4.008426666259766, 0.8539860844612122]
# Erro ao obter min_x para o objeto 89
# Erro ao obter as dimensões do objeto 89
# Posição do objeto 90: [-2.318000078201294, 4.22499942779541, 1.4730206727981567]
# Dimensões do objeto 90 - Largura: 0.22150786221027374, Altura: 0.16335055232048035
# Posição do objeto 91: [-2.296632766723633, 4.2253241539001465, 1.5360206365585327]
# Dimensões do objeto 91 - Largura: 0.22150786221027374, Altura: 0.16335055232048035
# Posição do objeto 92: [-2.315570831298828, 4.335851669311523, 0.9077792763710022]
# Dimensões do objeto 92 - Largura: 0.9298785924911499, Altura: 0.6066475734114647
# Posição do objeto 93: [-2.3096587657928467, 4.297050952911377, 0.6734969019889832]
# Dimensões do objeto 93 - Largura: 0.22062452137470245, Altura: 0.31915830075740814
# Posição do objeto 94: [-2.3029003143310547, 4.333026885986328, 0.5146697163581848]
# Dimensões do objeto 94 - Largura: 0.5207583019509912, Altura: 0.31173115968704224
# Posição do objeto 95: [-2.312345027923584, 4.311341762542725, 0.27869993448257446]
# Dimensões do objeto 95 - Largura: 0.18480221927165985, Altura: 0.3110657185316086
# Posição do objeto 96: [-2.3131959438323975, 4.311642646789551, 0.2541099786758423]
# Erro ao obter min_x para o objeto 96
# Erro ao obter as dimensões do objeto 96
# Posição do objeto 97: [-2.3216421604156494, 4.301915168762207, 0.1038200706243515]
# Dimensões do objeto 97 - Largura: 0.10451129684224725, Altura: 0.2911830246448517
# Posição do objeto 98: [-2.245973587036133, 4.302134990692139, 0.052479423582553864]
# Dimensões do objeto 98 - Largura: 0.2905838191509247, Altura: 0.10073766112327576
# Posição do objeto 99: [-2.2440757751464844, 4.306506633758545, 0.019789399579167366]
# Erro ao obter min_x para o objeto 99
# Erro ao obter as dimensões do objeto 99
# Posição do objeto 100: [-2.315570831298828, 4.114147186279297, 0.907779335975647]
# Dimensões do objeto 100 - Largura: 0.9260767810046673, Altura: 0.6064602583646774
# Posição do objeto 101: [-2.310922145843506, 4.144172191619873, 0.6721265316009521]
# Dimensões do objeto 101 - Largura: 0.18988943099975586, Altura: 0.3153284266591072
# Posição do objeto 102: [-2.3029003143310547, 4.11698055267334, 0.5146697759628296]
# Dimensões do objeto 102 - Largura: 0.5205938210710883, Altura: 0.3092600777745247
# Posição do objeto 103: [-2.3124303817749023, 4.137718200683594, 0.2786232829093933]
# Dimensões do objeto 103 - Largura: 0.1536349058151245, Altura: 0.3079526275396347
# Posição do objeto 104: [-2.3137097358703613, 4.137792587280273, 0.2541097104549408]
# Erro ao obter min_x para o objeto 104
# Erro ao obter as dimensões do objeto 104
# Posição do objeto 105: [-2.3216421604156494, 4.148100852966309, 0.10382002592086792]
# Dimensões do objeto 105 - Largura: 0.1045113451546058, Altura: 0.29118283092975616
# Posição do objeto 106: [-2.246487617492676, 4.147301197052002, 0.05247955024242401]
# Dimensões do objeto 106 - Largura: 0.29058361053466797, Altura: 0.1007377952337265
# Posição do objeto 107: [-2.2445898056030273, 4.142929553985596, 0.01724334992468357]
# Erro ao obter min_x para o objeto 107
# Erro ao obter as dimensões do objeto 107
# Posição do objeto 108: [-0.675000011920929, -1.875, 0.0]
# Dimensões do objeto 108 - Largura: 0.7618995606899261, Altura: 0.5585218369960785
# Posição do objeto 109: [-0.6752834320068359, -1.928769588470459, 0.05247953161597252]
# Dimensões do objeto 109 - Largura: 1.2716959789395332, Altura: 0.5585218369960785
# Posição do objeto 110: [-0.6749993562698364, -1.8533577919006348, 0.10382004082202911]
# Dimensões do objeto 110 - Largura: 1.2344445064663887, Altura: 0.6488734111189842
# Posição do objeto 111: [-0.6753076910972595, -1.8633416891098022, 0.27852457761764526]
# Dimensões do objeto 111 - Largura: 0.6694923788309097, Altura: 0.5591826438903809
# Posição do objeto 112: [-0.6749999523162842, -1.8720998764038086, 0.5146697759628296]
# Dimensões do objeto 112 - Largura: 0.9885990470647812, Altura: 0.648873396217823
# Posição do objeto 113: [-0.6753095984458923, -1.7123582363128662, 0.515228807926178]
# Dimensões do objeto 113 - Largura: 0.9985989779233932, Altura: 0.5578314960002899
# Posição do objeto 114: [-0.6749300956726074, -1.4789903163909912, 0.5019991993904114]
# Dimensões do objeto 114 - Largura: 0.5887583792209625, Altura: 0.9454077631235123
# Posição do objeto 115: [-0.6746269464492798, -1.4744631052017212, 0.7402259111404419]
# Dimensões do objeto 115 - Largura: 0.3417682647705078, Altura: 0.5582375526428223
# Posição do objeto 116: [-0.6749305725097656, -1.4765610694885254, 1.0672403573989868]
# Dimensões do objeto 116 - Largura: 0.22150786221027374, Altura: 0.16335055232048035
# Posição do objeto 117: [-0.6746066212654114, -1.497928261756897, 1.1302403211593628]
# Dimensões do objeto 117 - Largura: 0.22150786221027374, Altura: 0.16335055232048035
# Posição do objeto 118: [-0.8900018930435181, -1.4657849073410034, 0.8853845000267029]
# Dimensões do objeto 118 - Largura: 0.34905386716127396, Altura: 0.12061433121562004
# Posição do objeto 119: [-0.8854212164878845, -1.4371088743209839, 0.7374362349510193]
# Dimensões do objeto 119 - Largura: 0.38467366248369217, Altura: 0.12061431258916855
# Posição do objeto 120: [-0.8900005221366882, -1.4235576391220093, 0.6463987231254578]
# Dimensões do objeto 120 - Largura: 0.3689206428825855, Altura: 0.37688669189810753
# Posição do objeto 121: [-0.8904512524604797, -1.5314362049102783, 0.48499804735183716]
# Dimensões do objeto 121 - Largura: 0.08825063705444336, Altura: 0.11735254526138306
# Posição do objeto 122: [-0.8915482759475708, -1.5282342433929443, 0.48246124386787415]
# Erro ao obter min_x para o objeto 122
# Erro ao obter as dimensões do objeto 122
# Posição do objeto 123: [-0.459829717874527, -1.4657981395721436, 0.8853846192359924]
# Dimensões do objeto 123 - Largura: 0.34998707473278046, Altura: 0.13335226476192474
# Posição do objeto 124: [-0.4642779231071472, -1.437847375869751, 0.7372764348983765]
# Dimensões do objeto 124 - Largura: 0.385314017534256, Altura: 0.13335228338837624
# Posição do objeto 125: [-0.45982831716537476, -1.4235738515853882, 0.6463981866836548]
# Dimensões do objeto 125 - Largura: 0.37110137566924095, Altura: 0.3785056918859482
# Posição do objeto 126: [-0.45891273021698, -1.531775951385498, 0.48518747091293335]
# Dimensões do objeto 126 - Largura: 0.09474897384643555, Altura: 0.1128307431936264
# Posição do objeto 127: [-0.45868223905563354, -1.5282819271087646, 0.4824744462966919]
# Erro ao obter min_x para o objeto 127
# Erro ao obter as dimensões do objeto 127
# Posição do objeto 128: [-0.6752642393112183, -1.8615365028381348, 0.2541128993034363]
# Erro ao obter min_x para o objeto 128
# Erro ao obter as dimensões do objeto 128
# Posição do objeto 129: [-0.6752835512161255, -1.9306672811508179, 0.01978931948542595]
# Erro ao obter min_x para o objeto 129
# Erro ao obter as dimensões do objeto 129
# Posição do objeto 130: [3.6500000953674316, -3.200000047683716, 1.2000000476837158]
# Dimensões do objeto 130 - Largura: 0.1700001358985901, Altura: 1.7500009536743164
# Posição do objeto 131: [3.6500000953674316, -3.200000047683716, 1.2000000476837158]
# Erro ao obter min_x para o objeto 131
# Erro ao obter as dimensões do objeto 131
# Posição do objeto 132: [3.65000057220459, -3.1996355056762695, 1.200000524520874]
# Erro ao obter min_x para o objeto 132
# Erro ao obter as dimensões do objeto 132
# Posição do objeto 133: [3.6500000953674316, -2.75, 0.8499998450279236]
# Dimensões do objeto 133 - Largura: 0.14000028371810913, Altura: 1.9200001955032349
# Posição do objeto 134: [3.64500093460083, -2.825000286102295, 0.9620001912117004]
# Dimensões do objeto 134 - Largura: 0.14001072198152542, Altura: 0.9006901979446411
# Posição do objeto 135: [3.6449999809265137, -2.825000286102295, 0.9600002765655518]
# Dimensões do objeto 135 - Largura: 0.14000028371810913, Altura: 0.9000002145767212
# Posição do objeto 136: [4.079218864440918, -3.5732738971710205, 0.006000041961669922]
# Erro ao obter min_x para o objeto 136
# Erro ao obter as dimensões do objeto 136
# Posição do objeto 137: [3.219219446182251, -3.5732738971710205, 0.006000041961669922]
# Erro ao obter min_x para o objeto 137
# Erro ao obter as dimensões do objeto 137
# Posição do objeto 138: [3.750002861022949, -4.099997043609619, 1.200000524520874]
# Dimensões do objeto 138 - Largura: 0.2600037604570389, Altura: 0.20500700920820236
# Posição do objeto 139: [3.75, -4.102498531341553, 1.2000020742416382]
# Dimensões do objeto 139 - Largura: 0.2600037753582001, Altura: 0.20500701665878296
# Posição do objeto 140: [3.5250027179718018, -4.174996852874756, 1.200000524520874]
# Dimensões do objeto 140 - Largura: 0.2600037604570389, Altura: 0.20500700920820236
# Posição do objeto 141: [3.5250000953674316, -4.1774983406066895, 1.2000020742416382]
# Dimensões do objeto 141 - Largura: 0.2600037753582001, Altura: 0.20500701665878296
# Posição do objeto 142: [3.450002908706665, -4.374997138977051, 1.200000524520874]
# Dimensões do objeto 142 - Largura: 0.2600037604570389, Altura: 0.20500700920820236
# Posição do objeto 143: [3.450000047683716, -4.377498626708984, 1.2000020742416382]
# Dimensões do objeto 143 - Largura: 0.2600037753582001, Altura: 0.20500701665878296
# Posição do objeto 144: [3.325002908706665, -4.549996852874756, 1.200000524520874]
# Dimensões do objeto 144 - Largura: 0.2600037604570389, Altura: 0.20500700920820236
# Posição do objeto 145: [3.325000047683716, -4.5524983406066895, 1.2000020742416382]
# Dimensões do objeto 145 - Largura: 0.2600037753582001, Altura: 0.20500701665878296
# Posição do objeto 146: [3.1500027179718018, -4.774997234344482, 1.200000524520874]
# Dimensões do objeto 146 - Largura: 0.2600037604570389, Altura: 0.20500700920820236
# Posição do objeto 147: [3.1500000953674316, -4.777498722076416, 1.2000020742416382]
# Dimensões do objeto 147 - Largura: 0.2600037753582001, Altura: 0.20500701665878296
# Posição do objeto 148: [3.0500028133392334, -4.899997234344482, 1.200000524520874]
# Dimensões do objeto 148 - Largura: 0.2600037604570389, Altura: 0.20500700920820236
# Posição do objeto 149: [3.049999952316284, -4.902498722076416, 1.2000020742416382]
# Dimensões do objeto 149 - Largura: 0.2600037753582001, Altura: 0.20500701665878296
# Posição do objeto 150: [-4.800000190734863, 4.575000286102295, 0.9850001335144043]
# Dimensões do objeto 150 - Largura: 0.6000582277774811, Altura: 1.2195016145706177
# Posição do objeto 151: [-4.800000190734863, 4.575000286102295, 0.9850001335144043]
# Erro ao obter min_x para o objeto 151
# Erro ao obter as dimensões do objeto 151
# Posição do objeto 152: [-4.800000190734863, 4.574999809265137, 0.9850000143051147]
# Dimensões do objeto 152 - Largura: 0.5800010561943054, Altura: 1.2001341581344604
# Posição do objeto 153: [-4.510000228881836, 5.175000190734863, 1.0]
# Dimensões do objeto 153 - Largura: 0.020114519062190084, Altura: 0.5996340718120337
# Posição do objeto 154: [-4.5, 4.885300636291504, 1.0350008010864258]
# Dimensões do objeto 154 - Largura: 0.02000528573989868, Altura: 0.5993689894676208
# Posição do objeto 155: [-4.510000228881836, 3.9749999046325684, 0.9999999403953552]
# Dimensões do objeto 155 - Largura: 0.020010098812690558, Altura: 0.5995148560032248
# Posição do objeto 156: [-4.499999523162842, 4.265500068664551, 1.0349998474121094]
# Dimensões do objeto 156 - Largura: 0.02000504732131958, Altura: 0.5992575287818909
# Posição do objeto 157: [-0.5499999523162842, 4.275000095367432, 0.9850001335144043]
# Dimensões do objeto 157 - Largura: 0.6000582277774811, Altura: 1.2195016145706177
# Posição do objeto 158: [-0.5499999523162842, 4.275000095367432, 0.9850001335144043]
# Erro ao obter min_x para o objeto 158
# Erro ao obter as dimensões do objeto 158
# Posição do objeto 159: [-0.550000011920929, 4.275000095367432, 0.9850000143051147]
# Dimensões do objeto 159 - Largura: 0.5800010561943054, Altura: 1.2001341581344604
# Posição do objeto 160: [-0.25999999046325684, 4.875, 1.0]
# Dimensões do objeto 160 - Largura: 0.020114519062190084, Altura: 0.5996340718120337
# Posição do objeto 161: [-0.2499997764825821, 4.585300445556641, 1.0350008010864258]
# Dimensões do objeto 161 - Largura: 0.02000528573989868, Altura: 0.5993689894676208
# Posição do objeto 162: [-0.25999999046325684, 3.674999952316284, 0.9999999403953552]
# Dimensões do objeto 162 - Largura: 0.020010098812690558, Altura: 0.5995148560032248
# Posição do objeto 163: [-0.2499997466802597, 3.9655001163482666, 1.0349998474121094]
# Dimensões do objeto 163 - Largura: 0.02000504732131958, Altura: 0.5992575287818909
# Posição do objeto 164: [-4.699999809265137, 0.5500000715255737, 0.9850001335144043]
# Dimensões do objeto 164 - Largura: 0.6000582277774811, Altura: 1.2195016145706177
# Posição do objeto 165: [-4.699999809265137, 0.5500000715255737, 0.9850001335144043]
# Erro ao obter min_x para o objeto 165
# Erro ao obter as dimensões do objeto 165
# Posição do objeto 166: [-4.699999809265137, 0.550000011920929, 0.9850000143051147]
# Dimensões do objeto 166 - Largura: 0.5800010561943054, Altura: 1.2001341581344604
# Posição do objeto 167: [-4.409999847412109, 1.149999976158142, 1.0]
# Dimensões do objeto 167 - Largura: 0.020114519062190084, Altura: 0.5996340718120337
# Posição do objeto 168: [-4.399999618530273, 0.8603004217147827, 1.0350008010864258]
# Dimensões do objeto 168 - Largura: 0.02000528573989868, Altura: 0.5993689894676208
# Posição do objeto 169: [-4.409999847412109, -0.05000003054738045, 0.9999999403953552]
# Dimensões do objeto 169 - Largura: 0.020010098812690558, Altura: 0.5995148560032248
# Posição do objeto 170: [-4.399999618530273, 0.24050001800060272, 1.0349998474121094]
# Dimensões do objeto 170 - Largura: 0.02000504732131958, Altura: 0.5992575287818909
# Posição do objeto 171: [-2.049999952316284, 0.9000000357627869, 0.9850001335144043]
# Dimensões do objeto 171 - Largura: 0.6000582277774811, Altura: 1.2195016145706177
# Posição do objeto 172: [-2.049999952316284, 0.9000000357627869, 0.9850001335144043]
# Erro ao obter min_x para o objeto 172
# Erro ao obter as dimensões do objeto 172
# Posição do objeto 173: [-2.049999952316284, 0.8999999761581421, 0.9850000143051147]
# Dimensões do objeto 173 - Largura: 0.5800010561943054, Altura: 1.2001341581344604
# Posição do objeto 174: [-1.7599999904632568, 1.5, 1.0]
# Dimensões do objeto 174 - Largura: 0.020114519062190084, Altura: 0.5996340718120337
# Posição do objeto 175: [-1.749999761581421, 1.2103004455566406, 1.0350008010864258]
# Dimensões do objeto 175 - Largura: 0.02000528573989868, Altura: 0.5993689894676208
# Posição do objeto 176: [-1.7599999904632568, 0.29999998211860657, 0.9999999403953552]
# Dimensões do objeto 176 - Largura: 0.020010098812690558, Altura: 0.5995148560032248
# Posição do objeto 177: [-1.749999761581421, 0.590499997138977, 1.0349998474121094]
# Dimensões do objeto 177 - Largura: 0.02000504732131958, Altura: 0.5992575287818909
# Posição do objeto 178: [2.299999952316284, 2.0250000953674316, 0.9850001335144043]
# Dimensões do objeto 178 - Largura: 0.6000582277774811, Altura: 1.2195016145706177
# Posição do objeto 179: [2.299999952316284, 2.0250000953674316, 0.9850001335144043]
# Erro ao obter min_x para o objeto 179
# Erro ao obter as dimensões do objeto 179
# Posição do objeto 180: [2.299999952316284, 2.0250000953674316, 0.9850000143051147]
# Dimensões do objeto 180 - Largura: 0.5800010561943054, Altura: 1.2001341581344604
# Posição do objeto 181: [2.5899999141693115, 2.625, 1.0]
# Dimensões do objeto 181 - Largura: 0.020114519062190084, Altura: 0.5996340718120337
# Ignorando o objeto 181 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 182: [2.6000001430511475, 2.3353004455566406, 1.0350008010864258]
# Dimensões do objeto 182 - Largura: 0.02000528573989868, Altura: 0.5993689894676208
# Ignorando o objeto 182 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 183: [2.5899999141693115, 1.4249999523162842, 0.9999999403953552]
# Dimensões do objeto 183 - Largura: 0.020010098812690558, Altura: 0.5995148560032248
# Ignorando o objeto 183 por estar dentro da área ao redor do Pioneer ou Goal
# Posição do objeto 184: [2.6000001430511475, 1.715499997138977, 1.0349998474121094]
# Dimensões do objeto 184 - Largura: 0.02000504732131958, Altura: 0.5992575287818909
# Ignorando o objeto 184 por estar dentro da área ao redor do Pioneer ou Goal
# Desconectado do CoppeliaSim

# %%
# Criar os subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Espaço de ocupação no primeiro subplot
for rect in rectangles:
    x, y, width, height = rect
    ax1.add_patch(plt.Rectangle((x - width/2, y - height/2), width, height, edgecolor='r', facecolor='r'))  # Retângulos sólidos

# Marcar a posição do Pioneer com um quadrado azul
pioneer_square = plt.Rectangle((pioneer_pos[0] - 0.5, pioneer_pos[1] - 0.5), 1, 1, edgecolor='blue', facecolor='blue')
ax1.add_patch(pioneer_square)

# Marcar a posição do Goal com uma estrela verde
ax1.plot(goal_pos[0], goal_pos[1], marker='*', color='green', markersize=10, label='Goal')

ax1.set_xlim(-5, 5)  # Ajuste os limites conforme necessário
ax1.set_ylim(-5, 5)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Espaço de Ocupação no Plano XY')
ax1.set_aspect('equal', adjustable='box')

# Adicionar legenda ao primeiro subplot
ax1.legend()

# Espaço de configuração no segundo subplot
for rect in rectangles:
    x, y, width, height = rect
    width = width + 1
    height = height + 1
    ax2.add_patch(plt.Rectangle((x - width/2, y - height/2), width, height, edgecolor='r', facecolor='r'))  # Retângulos sólidos

# Marcar a posição do Pioneer com um triângulo azul
ax2.plot(pioneer_pos[0], pioneer_pos[1], marker='.', color='blue', markersize=10, label='Pioneer')

# Marcar a posição do Goal com uma estrela verde
ax2.plot(goal_pos[0], goal_pos[1], marker='*', color='green', markersize=10, label='Goal')

ax2.set_xlim(-5, 5)  # Ajuste os limites conforme necessário
ax2.set_ylim(-5, 5)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Espaço de Configuração 2D')
ax2.set_aspect('equal', adjustable='box')

# Adicionar legenda ao segundo subplot
ax2.legend()

# Ajustar o layout para melhor visualização
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

pioneer_pos = np.array(pioneer_pos[0:2])
goal_pos = np.array([3.45000005, 2.2249999 ])

print(pioneer_pos)
print(goal_pos) #[3.45000005 2.2249999 ]

xi = 500
eta = 40
Q_star = 1
R_switch = 2.0 

x = np.linspace(-5, 5, 1000)
y = np.linspace(-5, 5, 1000)
X, Y = np.meshgrid(x, y)

def attractive_potential(X, Y, goal, R_switch, xi):
    dist = np.sqrt((X - goal[0])**2 + (Y - goal[1])**2)
    U_att = np.zeros_like(dist)
    
    mask_conic = dist > R_switch
    U_att[mask_conic] = xi * (dist[mask_conic] - R_switch)
    
    mask_paraboloid = dist <= R_switch
    U_att[mask_paraboloid] = 0.5 * xi * dist[mask_paraboloid]**2
    
    return U_att

def repulsive_potential(X, Y, obstacles, Q_star):
    U_rep = np.zeros_like(X)
    for rect in obstacles:
        x, y, width, height = rect
        dist_x = np.maximum(0, np.abs(X - x) - (width+1)/2)
        dist_y = np.maximum(0, np.abs(Y - y) - (height+1)/2)
        dist = np.sqrt(dist_x**2 + dist_y**2)
        mask = dist < Q_star
        U_rep[mask] += 0.5 * eta * (1.0 / (0.1 + dist[mask]) - 1.0 / (0.1 + Q_star))**2
    return U_rep

U_att = attractive_potential(X, Y, goal_pos,R_switch,xi)
U_rep = repulsive_potential(X, Y, rectangles, Q_star)
U_tot = U_att + U_rep

grad_U_x, grad_U_y = np.gradient(U_tot, x, y)

path = [pioneer_pos.copy()]
current_pos = pioneer_pos.copy()
alpha = 0.01
threshold = 0.1
max_try = 0

while np.linalg.norm(current_pos - goal_pos) > threshold:

    # Find the closest grid point indices
    ix = np.argmin(np.abs(x - current_pos[0]))
    iy = np.argmin(np.abs(y - current_pos[1]))
    
    # Get the gradient at the current position
    grad = np.array([grad_U_y[ix, iy],grad_U_x[ix, iy]])
    
    # Update position by moving opposite to the gradient
    force = -grad
    current_pos += alpha * force
    path.append(current_pos.copy())

    max_try = max_try + 1
    if(max_try > 1000):
        break

print(f"Resultado com: {max_try}")

path = np.array(path)

fig, ax3 = plt.subplots(1, 1, figsize=(18, 6))


c = ax3.contourf(X, Y, U_tot, levels=50, cmap='jet')
ax3.plot(path[:, 0], path[:, 1], marker='.', color='white', label='Path')
ax3.plot(goal_pos[0], goal_pos[1], marker='*', color='green', markersize=10, label='Goal')

ax3.set_xlim(-5, 5)
ax3.set_ylim(-5, 5)
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_title('Campo de Potencial e Caminho Planejado')
ax3.set_aspect('equal', adjustable='box')


ax3.legend()

fig.colorbar(c, ax=ax3)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 pioneer_pos = np.array(pioneer_pos[0:2])
#       5 goal_pos = np.array([3.45000005, 2.2249999 ])
#       7 print(pioneer_pos)
#
# NameError: name 'pioneer_pos' is not defined
